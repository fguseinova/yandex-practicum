# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта-и-данных" data-toc-modified-id="Описание-проекта-и-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта и данных</a></span><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#План-работы" data-toc-modified-id="План-работы-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>План работы</a></span></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Импорт-библиотек-для-работы" data-toc-modified-id="Импорт-библиотек-для-работы-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Импорт библиотек для работы</a></span></li><li><span><a href="#Загрузка-файлов-с-данными" data-toc-modified-id="Загрузка-файлов-с-данными-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Загрузка файлов с данными</a></span></li><li><span><a href="#Проверка-правильности-расчета-эффективности-обогащения" data-toc-modified-id="Проверка-правильности-расчета-эффективности-обогащения-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Проверка правильности расчета эффективности обогащения</a></span></li><li><span><a href="#Анализ-признаков,-недоступных-в-тестовой-выборке" data-toc-modified-id="Анализ-признаков,-недоступных-в-тестовой-выборке-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Анализ признаков, недоступных в тестовой выборке</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Предобработка данных</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Анализ-динамики-концентраций-металлов-на-этапах" data-toc-modified-id="Анализ-динамики-концентраций-металлов-на-этапах-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Анализ динамики концентраций металлов на этапах</a></span></li><li><span><a href="#Анализ-размеров-гранул-сырья" data-toc-modified-id="Анализ-размеров-гранул-сырья-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Анализ размеров гранул сырья</a></span></li><li><span><a href="#Исследование-суммарной-концентрации-веществ-на-разных-этапах" data-toc-modified-id="Исследование-суммарной-концентрации-веществ-на-разных-этапах-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Исследование суммарной концентрации веществ на разных этапах</a></span></li></ul></li><li><span><a href="#Моделирование" data-toc-modified-id="Моделирование-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Моделирование</a></span><ul class="toc-item"><li><span><a href="#Добавление-функции-для-итоговой-метрики-sMAPE" data-toc-modified-id="Добавление-функции-для-итоговой-метрики-sMAPE-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Добавление функции для итоговой метрики sMAPE</a></span></li><li><span><a href="#Разбиение-на-таргет-и-фичи" data-toc-modified-id="Разбиение-на-таргет-и-фичи-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Разбиение на таргет и фичи</a></span></li><li><span><a href="#Масштабирование-данных" data-toc-modified-id="Масштабирование-данных-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Масштабирование данных</a></span></li><li><span><a href="#Прогнозирование-переменной-rough.output.recovery" data-toc-modified-id="Прогнозирование-переменной-rough.output.recovery-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Прогнозирование переменной rough.output.recovery</a></span><ul class="toc-item"><li><span><a href="#Dummy-Regressor" data-toc-modified-id="Dummy-Regressor-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Dummy Regressor</a></span></li><li><span><a href="#Linear-Regression" data-toc-modified-id="Linear-Regression-4.4.2"><span class="toc-item-num">4.4.2&nbsp;&nbsp;</span>Linear Regression</a></span></li><li><span><a href="#Decision-Tree" data-toc-modified-id="Decision-Tree-4.4.3"><span class="toc-item-num">4.4.3&nbsp;&nbsp;</span>Decision Tree</a></span></li><li><span><a href="#Random-Forest" data-toc-modified-id="Random-Forest-4.4.4"><span class="toc-item-num">4.4.4&nbsp;&nbsp;</span>Random Forest</a></span></li></ul></li><li><span><a href="#Прогнозирование-переменной-final.output.recovery" data-toc-modified-id="Прогнозирование-переменной-final.output.recovery-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Прогнозирование переменной final.output.recovery</a></span><ul class="toc-item"><li><span><a href="#Dummy-Regressor" data-toc-modified-id="Dummy-Regressor-4.5.1"><span class="toc-item-num">4.5.1&nbsp;&nbsp;</span>Dummy Regressor</a></span></li><li><span><a href="#Linear-Regression" data-toc-modified-id="Linear-Regression-4.5.2"><span class="toc-item-num">4.5.2&nbsp;&nbsp;</span>Linear Regression</a></span></li><li><span><a href="#Decision-Tree" data-toc-modified-id="Decision-Tree-4.5.3"><span class="toc-item-num">4.5.3&nbsp;&nbsp;</span>Decision Tree</a></span></li><li><span><a href="#Random-Forest" data-toc-modified-id="Random-Forest-4.5.4"><span class="toc-item-num">4.5.4&nbsp;&nbsp;</span>Random Forest</a></span></li></ul></li></ul></li><li><span><a href="#Финальное-тестирование" data-toc-modified-id="Финальное-тестирование-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Финальное тестирование</a></span></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# ## Описание проекта и данных

# %% [markdown]
# ### Описание проекта

# %% [markdown]
# Необходимо подготовить прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Нужно использовать данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.

# %% [markdown]
# ### Описание данных

# %% [markdown]
# Данные находятся в трёх файлах:
#
# - `gold_recovery_train_new.csv` — обучающая выборка;
# - `gold_recovery_test_new.csv` — тестовая выборка;
# - `gold_recovery_full_new.csv` — исходные данные.
#
# Данные индексируются датой и временем получения информации (признак `date`). Соседние по времени параметры часто похожи.
#
# Некоторые параметры недоступны, потому что замеряются и/или рассчитываются значительно позже. Из-за этого в тестовой выборке отсутствуют некоторые признаки, которые могут быть в обучающей. Также в тестовом наборе нет целевых признаков.
#
# Исходный датасет содержит обучающую и тестовую выборки со всеми признаками.
#
# В нашем распоряжении сырые данные: их просто выгрузили из хранилища. Прежде чем приступить к построению модели, нужно проверить их на корректность.

# %% [markdown]
# **Технологический процесс**
#
# - *Rougher feed* — исходное сырье
# - *Rougher additions* (или *reagent additions*) — флотационные реагенты: *Xanthate, Sulphate, Depressant*
#     - *Xanthate* *— ксантогенат (промотер, или активатор флотации);
#     - *Sulphate* — сульфат (на данном производстве сульфид натрия);
#     - *Depressant* — депрессант (силикат натрия).
# - *Rougher process* (англ. «грубый процесс») — флотация
# - *Rougher tails* — отвальные хвосты
# - *Float banks* — флотационная установка
# - *Cleaner process* — очистка
# - *Rougher Au* — черновой концентрат золота
# - *Final Au* — финальный концентрат золота
#
# **Параметры этапов**
#
# - *air amount* — объём воздуха
# - *fluid levels* — уровень жидкости
# - *feed size* — размер гранул сырья
# - *feed rate —* скорость подачи

# %% [markdown]
# **Наименование признаков**
#
# Наименование признаков должно быть такое:
#
# `[этап].[тип_параметра].[название_параметра]`
#
# Пример: `rougher.input.feed_ag`
#
# Возможные значения для блока `[этап]`:
#
# - *rougher —* флотация
# - *primary_cleaner* — первичная очистка
# - *secondary_cleaner* — вторичная очистка
# - *final* — финальные характеристики
#
# Возможные значения для блока `[тип_параметра]`:
#
# - *input* — параметры сырья
# - *output* — параметры продукта
# - *state* — параметры, характеризующие текущее состояние этапа
# - *calculation —* расчётные характеристики

# %% [markdown]
# ### План работы

# %% [markdown]
# 1. Импортировать исходные данные.
# 1. Изучить исходные данные, предобработать данные.
# 1. Провести исследовательский анализ данных.
# 1. Подготовить данные (таргеты и признаки к построению моделей).
# 1. Построить модели для каждого целевого признака, выбрать наилучшие.
# 1. Проверить модели на тестовых выборках.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Импорт библиотек для работы

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

from sklearn.metrics import mean_absolute_error, make_scorer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Загрузка файлов с данными

# %%
# импортируем таблицы с данными
try:
    data_train = pd.read_csv('/datasets/gold_recovery_train_new.csv')
    data_test = pd.read_csv('/datasets/gold_recovery_test_new.csv')
    data_full = pd.read_csv('/datasets/gold_recovery_full_new.csv')
except:
    # здесь была ссылка на загрузку данных с Яндекса

# %%
# присвоим таблицам названия
data_train.name = 'Train'
data_test.name = 'Test'
data_full.name = 'Full'

# %%
pd.set_option('display.max_columns', None)

# %%
# посмотрим на исходные таблицы
for data in [data_train, data_test, data_full]:
    print(data.name)
    display(data.head())
    print()
# Out:
# Train
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %%
# посмотрим на информацию о таблицах
for data in [data_train, data_test, data_full]:
    print(data.info())
    print()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                14149 non-null  object
#  1   final.output.concentrate_ag                         14148 non-null  float64
#  2   final.output.concentrate_pb                         14148 non-null  float64
#  3   final.output.concentrate_sol                        13938 non-null  float64
#  4   final.output.concentrate_au                         14149 non-null  float64
#  5   final.output.recovery                               14149 non-null  float64
#  6   final.output.tail_ag                                14149 non-null  float64
#  7   final.output.tail_pb                                14049 non-null  float64
# ...

# %% [markdown]
# В целом все ок, кроме того, что во всех таблицах переменная `date` имеет формат `object`, следовательно, нужно будет на этапе предобработки это исправить.

# %%
# посмотрим на информацию о размерах таблиц
for data in [data_train, data_test, data_full]:
    print(data.name)
    print(data.shape)
# Out:
# Train
# (14149, 87)
# Test
# (5290, 53)
# Full
# (19439, 87)

# %%
# сделаем проверку соответствия числа наблюдений
data_train.shape[0] + data_test.shape[0] == data_full.shape[0]
# Out:
# True

# %% [markdown]
# Мы видим, что в число наблюдений в data_full действительно делится на наблюдения в data_train и data_test, но мы также видим, что в тестовой выборке число признаков ниже, чем в train.

# %%
# изучим пропуски в данных
for data in [data_train, data_test, data_full]:
    print(data.name)
    display(pd.DataFrame(round(data.isna().mean()*100, 0)).style.background_gradient('coolwarm'))
# Out:
# Train
# <style type="text/css">
# ...

# %% [markdown]
# Заметим, что пропусков не очень много, но они могут быть важны, т.к. это этапы обработки руды. Что делать с пропусками, решим позже.

# %% [markdown]
# ### Проверка правильности расчета эффективности обогащения

# %% [markdown]
# Эффективность обогащения рассчитывается по формуле
#
# $Recovery = \dfrac{C \times (F - T)}{F \times (C - T)} \times 100\%$,
# где:
#
# - *C* — доля золота в концентрате после флотации/очистки;
# - *F* — доля золота в сырье/концентрате до флотации/очистки;
# - *T* — доля золота в отвальных хвостах после флотации/очистки.
#
# Проверим, что эффективность обогащения рассчитана верно на обучающей выборке для признака `rougher.output.recovery`.

# %%
# создадим список rougher_output_recovery, в котором соберем рассчитанные нами эффективности

rougher_output_recovery = \
    data_train['rougher.output.concentrate_au'] * \
    (data_train['rougher.input.feed_au'] - data_train['rougher.output.tail_au']) \
    / (data_train['rougher.input.feed_au'] * \
    (data_train['rougher.output.concentrate_au'] - data_train['rougher.output.tail_au'])) \
    * 100

# рассчитаем MAE между нашим показателем и показателем из таблицы
round(mean_absolute_error(data_train['rougher.output.recovery'], rougher_output_recovery),4)
# Out:
# 0.0

# %% [markdown]
# Ошибка приближена к 0, следовательно, можем считать, что расчет произведен верно.

# %% [markdown]
# ### Анализ признаков, недоступных в тестовой выборке

# %% [markdown]
# Проанализируем признаки, недоступные в тестовой выборке.

# %%
set(data_train.columns.tolist()) - set(data_test.columns.tolist())
# Out:
# {'final.output.concentrate_ag',
#  'final.output.concentrate_au',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_au',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_au',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_au',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.recovery',
# ...

# %% [markdown]
# Похоже на то, что отсутствующие в тестовых данных столбцы соответствуют "выходным", а также расчетным параметрам (calculation), то есть наиболее вероятно, что значения, доступные в тестовых данных, известны до технологического процесса.
#
# Заметим также, что в датасете `data_test` отсутствуют столбцы `final.output.recovery` и `rougher.output.recovery`, являющиеся целевыми.

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# Обработаем столбцы с датой в каждой таблице. Для этого сначала вспомним, как выглядит дата:

# %%
data_test['date'][0]
# Out:
# '2016-09-01 00:59:59'

# %%
# обработаем столбцы с датой 
for data in [data_train, data_test, data_full]:
    data['date'] = pd.to_datetime(data['date'], format='%Y-%m-%d %H:%M:%S')
    # проверим, что данные обработались корректно
    print(type(data['date'].dtypes))
# Out:
# <class 'numpy.dtype[datetime64]'>
# <class 'numpy.dtype[datetime64]'>
# <class 'numpy.dtype[datetime64]'>

# %% [markdown]
# Даты обработались корректно.
#
# Проверим наличие дубликатов.

# %%
for data in [data_train, data_test, data_full]:
    print(f'{data.name}: {data.duplicated().sum()}')
# Out:
# Train: 0
# Test: 0
# Full: 0

# %% [markdown]
# Ни в одной из таблиц нет дубликатов.
#
# Обработаем пропуски в таблице. Посмотрим на некоторые из них.

# %%
data_train[data_train['final.output.tail_pb'].isna() == True].head()
# Out:
#                    date  final.output.concentrate_ag  \
# 345 2016-01-31 19:00:00                     8.662589
# 346 2016-01-31 20:00:00                     9.261812
# 347 2016-01-31 21:00:00                    10.378280
# 348 2016-01-31 22:00:00                    11.557897
# 349 2016-01-31 23:00:00                    11.023427
#
#      final.output.concentrate_pb  final.output.concentrate_sol  \
# 345                    10.001329                      8.532877
# 346                     9.601694                      8.394998
# 347                     9.133952                      7.655801
# 348                     8.530196                      7.424687
# 349                     7.695121                      3.294428
#
#      final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 345                    38.525578              75.114795             10.111156
# 346                    37.537394              72.425723             10.041515
# ...

# %% [markdown]
# Посмотрим теперь на соседние значения:

# %%
data_train.iloc[344:351, 7] # 7, т.к. столбец 'final.output.tail_pb' седьмой по счету с нуля
# Out:
# 344    0.148563
# 345         NaN
# 346         NaN
# 347         NaN
# 348         NaN
# 349         NaN
# 350    0.368370
# Name: final.output.tail_pb, dtype: float64

# %% [markdown]
# Можем заметить, что пропуски появляются последовательно на некоторых этапах. То есть в данном примере, на строке 344 данные были заполнены, затем на строках 345-349 данные были пропущены (с 19:00 до 23:00), после чего снова были заполнены. Это похоже на техническую ошибку.
#
# По логике технологического процесса значения для любого столбца будут либо постепенно возрастать, либо убывать (в зависимости от переменной). В данном случае логично заполнять строки при помощи линейной интерполяции. Применим метод `interpolate` для всей таблицы.

# %%
# заполним пропуски при помощи интерполяции
data_train = data_train.sort_values(by='date').set_index('date').interpolate()
data_test = data_test.sort_values(by='date').set_index('date').interpolate()
data_full = data_full.sort_values(by='date').set_index('date').interpolate()

# %%
# проверка 
data_train.iloc[344:351, 6] # 6, т.к. после того как дата стала индексом, -1 столбец
# Out:
# date
# 2016-01-31 18:00:00    0.148563
# 2016-01-31 19:00:00    0.185198
# 2016-01-31 20:00:00    0.221832
# 2016-01-31 21:00:00    0.258467
# 2016-01-31 22:00:00    0.295101
# 2016-01-31 23:00:00    0.331736
# 2016-02-01 00:00:00    0.368370
# Name: final.output.tail_pb, dtype: float64

# %% [markdown]
# Мы видим, что значения столбцов заполнились интерполяцией корректно.

# %% [markdown]
# Проверим, что пропусков больше нет:

# %%
for data in [data_train, data_test, data_full]:
    print(data.isna().sum().sum())
# Out:
# 0
# 0
# 0

# %% [markdown]
# Больше в таблицах нет пропусков.

# %% [markdown]
# **Вывод:**
#
# Мы загрузили исходные данные, изучили их, обработали пропуски, проверили наличие дубликатов, проверили корректность расчета эффективности обогащения, проанализировали недостающие данные, заполнили пропуски интерполяцией и далее можно приступать к более подробному анализу данных.

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Анализ динамики концентраций металлов на этапах

# %% [markdown]
# Посмотрим, как меняется концентрация металлов (*Au, Ag, Pb*) на различных этапах очистки.

# %%
concentration_dynamics = pd.DataFrame(columns=["feed", "rougher_output", "primary_cleaner_output", "final_output"])

concentration_dynamics.loc['Au', 'feed'] = data_full['rougher.input.feed_au'].mean()
concentration_dynamics.loc['Au', 'rougher_output'] = data_full['rougher.output.concentrate_au'].mean()
concentration_dynamics.loc['Au', 'primary_cleaner_output'] = data_full['primary_cleaner.output.concentrate_au'].mean()
concentration_dynamics.loc['Au', 'final_output'] = data_full['final.output.concentrate_au'].mean()

concentration_dynamics.loc['Ag', 'feed'] = data_full['rougher.input.feed_ag'].mean()
concentration_dynamics.loc['Ag', 'rougher_output'] = data_full['rougher.output.concentrate_ag'].mean()
concentration_dynamics.loc['Ag', 'primary_cleaner_output'] = data_full['primary_cleaner.output.concentrate_ag'].mean()
concentration_dynamics.loc['Ag', 'final_output'] = data_full['final.output.concentrate_ag'].mean()

concentration_dynamics.loc['Pb', 'feed'] = data_full['rougher.input.feed_pb'].mean()
concentration_dynamics.loc['Pb', 'rougher_output'] = data_full['rougher.output.concentrate_pb'].mean()
concentration_dynamics.loc['Pb', 'primary_cleaner_output'] = data_full['primary_cleaner.output.concentrate_pb'].mean()
concentration_dynamics.loc['Pb', 'final_output'] = data_full['final.output.concentrate_pb'].mean()

# %%
concentration_dynamics
# Out:
#         feed rougher_output primary_cleaner_output final_output
# Au  8.266097         19.772                32.1194    44.076513
# Ag  8.794927      11.994759               8.442408     5.168385
# Pb  3.585473       7.606272               9.810373     9.978819

# %%
concentration_dynamics.plot.bar();

# %% [markdown]
# Можем заметить, что концентрация золота поэтапно существенно повышалась, концентрация свинца – поэтапно, но незначительно увеличивалась, а вот концентрация серебра увеличилась на этапе флотации по сравнению с исходной концентрацией, затем стала снижаться.

# %% [markdown]
# ### Анализ размеров гранул сырья

# %% [markdown]
# Сравним распределения размеров гранул сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.

# %% [markdown]
# В исходных данных распределение гранул сырья встречается в следующих переменных:
# - `primary_cleaner.input.feed_size`;
# - `rougher.input.feed_size`.<br/>
#
# Таким образом, нам необходимо проанализировать распределение данных переменных в двух таблицах: `data_train` и `data_test`.

# %%
fig, ax = plt.subplots(figsize=(15,7))
sns.kdeplot(
    ax=ax, data=data_train, x='rougher.input.feed_size', 
    hue_norm=1, palette="crest", fill=True, alpha=.3, linewidth=0)
sns.kdeplot(
    ax=ax, data=data_test, x='rougher.input.feed_size', 
    hue_norm=1, palette="crest", fill=True, alpha=.3, linewidth=0)
plt.title('Распределение гранул сырья на этапе флотации', size=15)
ax.set_xlabel('Размеры гранул сырья на этапе флотации')
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,7))
sns.kdeplot(
    ax=ax, data=data_train, x='primary_cleaner.input.feed_size', 
    hue_norm=1, palette="crest", fill=True, alpha=.3, linewidth=0)
sns.kdeplot(
    ax=ax, data=data_test, x='primary_cleaner.input.feed_size', 
    hue_norm=1, palette="crest", fill=True, alpha=.3, linewidth=0)
plt.title('Распределение гранул сырья на первичном этапе очистки', size=15)
ax.set_xlabel('Размеры гранул сырья на первичном этапе очистки')
plt.grid()
plt.show()

# %% [markdown]
# В принципе распределения размеров гранул сырья на обучающей и тестовой выборках похожи между собой. Проверим дополнительно описательные статистики.

# %%
print('Train') 
display(data_train['rougher.input.feed_size'].describe())
print('Test')
display(data_test['rougher.input.feed_size'].describe())
# Out:
# Train
# count    14149.000000
# mean        60.097903
# std         23.023690
# min          9.659576
# 25%         48.950593
# 50%         55.269784
# 75%         65.982466
# max        484.967466
# Name: rougher.input.feed_size, dtype: float64
# Test
# count    5290.000000
# mean       55.952835
# std        19.080372
# min         0.046369
# 25%        43.906504
# 50%        50.846843
# 75%        62.451165
# max       392.494040
# Name: rougher.input.feed_size, dtype: float64

# %%
print('Train') 
display(data_train['primary_cleaner.input.feed_size'].describe())
print('Test')
display(data_test['primary_cleaner.input.feed_size'].describe())
# Out:
# Train
# count    14149.000000
# mean         7.322310
# std          0.614062
# min          1.080000
# 25%          6.960000
# 50%          7.290000
# 75%          7.700000
# max         10.470000
# Name: primary_cleaner.input.feed_size, dtype: float64
# Test
# count    5290.000000
# mean        7.266339
# std         0.610219
# min         5.650000
# 25%         6.890000
# 50%         7.250000
# 75%         7.600000
# max        15.500000
# Name: primary_cleaner.input.feed_size, dtype: float64

# %% [markdown]
# Они действительно похожи между собой средними, стандартными отклонениями, значениями квантилей, а также максимумами и минимумами.

# %% [markdown]
# ### Исследование суммарной концентрации веществ на разных этапах

# %% [markdown]
# Исследуем суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.

# %%
data_full['rougher.input.feed_total'] = (
    data_full['rougher.input.feed_au'] + data_full['rougher.input.feed_ag'] + \
    data_full['rougher.input.feed_pb'] + data_full['rougher.input.feed_sol']
)

data_full['rougher.output.concentrate_total'] = (
    data_full['rougher.output.concentrate_au'] + data_full['rougher.output.concentrate_ag'] + \
    data_full['rougher.output.concentrate_pb'] + data_full['rougher.output.concentrate_sol']
)

data_full['final.output.concentrate_total'] = (
    data_full['final.output.concentrate_au'] + data_full['final.output.concentrate_ag'] + \
    data_full['final.output.concentrate_pb'] + data_full['final.output.concentrate_sol']
)

# %%
data_full.loc[:, 'rougher.input.feed_total'].plot(
    kind='hist', figsize=(7,4), bins=100,
    title='Распределение суммарной концентрации в сырье');

# %%
data_full.loc[:, 'rougher.output.concentrate_total'].plot(
    kind='hist', figsize=(7,4), bins=100,
    title='Распределение суммарной концентрации в черновых концентратах');

# %%
data_full.loc[:, 'final.output.concentrate_total'].plot(
    kind='hist', figsize=(7,4), bins=100,
    title='Распределение суммарной концентрации в финальных концентратах');

# %% [markdown]
# В целом можно заметить, что по этапам среднее суммарной концентрации растет, а также дисперсия уменьшается – значения все сильнее концентрируются вокруг среднего.
# Из странностей можно заметить то, что в черновых концентратах резко возрастают "нули", что похоже на аномалии, от которых следует избавиться.
#
# Проверим, что среднее действительно растет:

# %%
print(data_full['rougher.input.feed_total'].mean())
print(data_full['rougher.output.concentrate_total'].mean())
print(data_full['final.output.concentrate_total'].mean())
# Out:
# 57.31797808554464
# 68.17457445820969
# 68.65930047408017

# %% [markdown]
# Удалим нулевые суммарные концентрации во всех трех случаях, т.к. это явно некорректно.

# %%
# избавимся от аномалий

# из сырья удалим строки с нулевым сырьем, 
# т.к. странно пускать на технолог.процесс сырье, в котором концентрация всех веществ по нулям
data_full = data_full.loc[data_full['rougher.input.feed_total'] != 0]
data_full = data_full.loc[data_full['rougher.output.concentrate_total'] != 0]
data_full = data_full.loc[data_full['final.output.concentrate_total'] != 0]

# %%
# проверим, что средние значения выросли
print(data_full['rougher.input.feed_total'].mean())
print(data_full['rougher.output.concentrate_total'].mean())
print(data_full['final.output.concentrate_total'].mean())
# Out:
# 57.32603074628391
# 69.57579819780653
# 69.00612373828262

# %% [markdown]
# **Вывод:**<br/>
# Мы проанализировали динамику концентраций металлов на разных этапах, проанализировали размеры гранул сырья, а также исследовали суммарную концентрацию веществ на разных этапах. В процессе были обнаружены нулевые суммарные концентрации, которые были приняты за аномалии и удалены. Теперь мы можем приступать к моделированию.

# %% [markdown]
# ## Моделирование

# %% [markdown]
# ### Добавление функции для итоговой метрики sMAPE

# %% [markdown]
# Напишем функцию для вычисления итоговой метрики качества sMAPE (Symmetric Mean Absolute Percentage Error).
#
# Итоговый sMAPE для двух целевых признаков `sMAPE_rougher` и `sMAPE_final` является средневзвешенным sMAPE с весами 0.25 и 0.75 для `sMAPE_rougher` и `sMAPE_final` соответственно: <br/>
# $ sMAPE = 0.25 \times sMAPE_{rougher} + 0.75 \times sMAPE_{final} $
#
# Для этого добавим две функции: для вычисления sMAPE на основе целевых и предсказанных значений и для вычисления итогового sMAPE по `sMAPE_rougher` и `sMAPE_final`.

# %%
def smape(target, predicted):
    if len(target) != len(predicted):
        return 'Ошибка, размеры векторов не совпадают'
    else:
        total = (np.abs(target - predicted) / ((np.abs(target) + np.abs(predicted)) / 2)).mean() * 100
        return total

# %%
def final_smape(smape_rougher, smape_final):
    return .25 * smape_rougher + .75 * smape_final

# %% [markdown]
# Для того, чтоб предсказывать целевые переменные `final.output.recovery` и `rougher.output.recovery`, нам нужно добавить их в таблицу `data_test`.

# %%
data_test = data_test.join(data_full[['rougher.output.recovery', 'final.output.recovery']])

# %% [markdown]
# Важный момент для дальнейшей работы: <br/>
# Поскольку ранее мы удалили аномалии с нулевыми суммарными концентрациями веществ из таблицы `data_full`, то теперь у нас в `data_test` могут быть пропуски там, где мы удалили аномалии. Проверим наличие пропусков:

# %%
data_test.isna().sum()
# Out:
# primary_cleaner.input.sulfate                   0
# primary_cleaner.input.depressant                0
# primary_cleaner.input.feed_size                 0
# primary_cleaner.input.xanthate                  0
# primary_cleaner.state.floatbank8_a_air          0
# primary_cleaner.state.floatbank8_a_level        0
# primary_cleaner.state.floatbank8_b_air          0
# primary_cleaner.state.floatbank8_b_level        0
# primary_cleaner.state.floatbank8_c_air          0
# primary_cleaner.state.floatbank8_c_level        0
# primary_cleaner.state.floatbank8_d_air          0
# primary_cleaner.state.floatbank8_d_level        0
# rougher.input.feed_ag                           0
# rougher.input.feed_pb                           0
# rougher.input.feed_rate                         0
# rougher.input.feed_size                         0
# rougher.input.feed_sol                          0
# rougher.input.feed_au                           0
# rougher.input.floatbank10_sulfate               0
# ...

# %% [markdown]
# Действительно, в столбцах добавленных из таблицы `data_full` появились пропуски, следовательно, теперь от этих строчек необходимо избавиться, т.к. с пропусками мы не сможем моделировать.

# %%
data_test = data_test.dropna()

# %% [markdown]
# ### Разбиение на таргет и фичи

# %%
# зададим целевые фичи в таргет и трейн
target_rougher_train = data_train['rougher.output.recovery']
target_final_train = data_train['final.output.recovery']
target_rougher_test = data_test['rougher.output.recovery']
target_final_test = data_test['final.output.recovery']

# зададим фичи в таргет и трейн
features_train = data_train.drop(labels=['rougher.output.recovery', 'final.output.recovery'], axis=1)
features_test = data_test.drop(labels=['rougher.output.recovery', 'final.output.recovery'], axis=1)

# удалим из features_train признаки, которых нет в тестовой выборке
differences = list(set(data_train.columns.tolist()) - set(data_test.columns.tolist()))
for column in differences:
    if column in features_train.columns.values.tolist():
        features_train = features_train.drop(labels=column, axis=1)

# %%
# проверим, что число фичей теперь соответствует числу фичей в трейне минус 2 (минус 2 целевых признака)
data_test.shape[1] - 2 == features_train.shape[1]
# Out:
# True

# %%
print(features_train.shape)
print(features_test.shape)
print()
print(target_rougher_train.shape)
print(target_rougher_test.shape)
print()
print(target_final_train.shape)
print(target_final_test.shape)
# Out:
# (14149, 52)
# (5154, 52)
#
# (14149,)
# (5154,)
#
# (14149,)
# (5154,)

# %% [markdown]
# Разбиение произведено корректно.

# %% [markdown]
# ### Масштабирование данных

# %%
scaler = StandardScaler()

# будем масштабировать все столбцы
numeric = features_train.columns.tolist()

scaler.fit(features_train[numeric])
features_train[numeric] = scaler.transform(features_train[numeric])
features_test[numeric] = scaler.transform(features_test[numeric])

# %% [markdown]
# ### Прогнозирование переменной rough.output.recovery

# %% [markdown]
# #### Dummy Regressor

# %%
# через make_scorer зададим скоринг по smape
scoring = make_scorer(smape, greater_is_better=False)

# %%
metrics = pd.DataFrame(columns=['score_rougher', 'score_final', 'score_total'])

# %%
model = DummyRegressor(strategy='median')
scores = cross_val_score(model, features_train, target_rougher_train, cv=5, scoring=scoring)
score = np.abs(sum(scores) / len(scores))
print('Средняя оценка качества модели:', score)

metrics.loc['Dummy Regressor', 'score_rougher'] = score
# Out:
# Средняя оценка качества модели: 11.886705556565618

# %% [markdown]
# #### Linear Regression

# %%
model = LinearRegression()
scores = cross_val_score(model, features_train, target_rougher_train, cv=5, scoring=scoring)
score = np.abs(sum(scores) / len(scores))
print('Средняя оценка качества модели:', score)

metrics.loc['Linear Regression', 'score_rougher'] = score
# Out:
# Средняя оценка качества модели: 12.767080592183692

# %% [markdown]
# Линейная регрессия предсказывает хуже дамми модели.

# %% [markdown]
# #### Decision Tree

# %%
model = DecisionTreeRegressor()

parameters = {
    'max_depth': range(1, 11),
    'min_samples_leaf': range(1, 6),
    'random_state': [12345]
}

grid = GridSearchCV(model, parameters, scoring=scoring, cv=5)
grid.fit(features_train, target_rougher_train)

print('Лучшие параметры:', grid.best_params_)
# Out:
# Лучшие параметры: {'max_depth': 5, 'min_samples_leaf': 4, 'random_state': 12345}

# %%
model = DecisionTreeRegressor(random_state=12345, max_depth=5, min_samples_leaf=4)
scores = cross_val_score(model, features_train, target_rougher_train, cv=5, scoring=scoring)
score = np.abs(sum(scores) / len(scores))
print('Средняя оценка качества модели:', score)

metrics.loc['Decision Tree', 'score_rougher'] = score
# Out:
# Средняя оценка качества модели: 11.282725218837806

# %% [markdown]
# Показатель дерева решений лучше, чем у дамми модели.

# %% [markdown]
# #### Random Forest

# %%
model = RandomForestRegressor()

parameters = {
    'max_depth': range(1, 6),
    'min_samples_leaf': range(1, 6),
    'n_estimators': range(1, 22, 10),
    'random_state': [12345]
}

grid = GridSearchCV(model, parameters, scoring=scoring, cv=5, verbose=2)
grid.fit(features_train, target_rougher_train)

print('Лучшие параметры:', grid.best_params_)
# Out:
# Fitting 5 folds for each of 75 candidates, totalling 375 fits
# [CV] END max_depth=1, min_samples_leaf=1, n_estimators=1, random_state=12345; total time=   0.1s
# [CV] END max_depth=1, min_samples_leaf=1, n_estimators=1, random_state=12345; total time=   0.1s
# [CV] END max_depth=1, min_samples_leaf=1, n_estimators=1, random_state=12345; total time=   0.1s
# [CV] END max_depth=1, min_samples_leaf=1, n_estimators=1, random_state=12345; total time=   0.1s
# [CV] END max_depth=1, min_samples_leaf=1, n_estimators=1, random_state=12345; total time=   0.1s
# [CV] END max_depth=1, min_samples_leaf=1, n_estimators=11, random_state=12345; total time=   0.7s
# [CV] END max_depth=1, min_samples_leaf=1, n_estimators=11, random_state=12345; total time=   0.6s
# [CV] END max_depth=1, min_samples_leaf=1, n_estimators=11, random_state=12345; total time=   0.5s
# [CV] END max_depth=1, min_samples_leaf=1, n_estimators=11, random_state=12345; total time=   0.5s
# ...

# %%
model = RandomForestRegressor(random_state=12345, max_depth=5, min_samples_leaf=1, n_estimators=21)
scores = cross_val_score(model, features_train, target_rougher_train, cv=5, scoring=scoring)
score = np.abs(sum(scores) / len(scores))
print('Средняя оценка качества модели:', score)

metrics.loc['Random Forest', 'score_rougher'] = score
# Out:
# Средняя оценка качества модели: 10.981461990000508

# %% [markdown]
# Таким образом, наилучший прогноз получился у случайного леса с параметрами `max_depth=5, min_samples_leaf=1, n_estimators=21`.

# %% [markdown]
# ### Прогнозирование переменной final.output.recovery

# %% [markdown]
# #### Dummy Regressor

# %%
model = DummyRegressor(strategy='median')
scores = cross_val_score(model, features_train, target_final_train, cv=5, scoring=scoring)
score = np.abs(sum(scores) / len(scores))
print('Средняя оценка качества модели:', score)

metrics.loc['Dummy Regressor', 'score_final'] = score
# Out:
# Средняя оценка качества модели: 11.343681206563113

# %% [markdown]
# #### Linear Regression

# %%
model = LinearRegression()
scores = cross_val_score(model, features_train, target_final_train, cv=5, scoring=scoring)
score = np.abs(sum(scores) / len(scores))
print('Средняя оценка качества модели:', score)

metrics.loc['Linear Regression', 'score_final'] = score
# Out:
# Средняя оценка качества модели: 12.268815742292983

# %% [markdown]
# В данном случае линейная регрессия опять показала себя хуже, чем дамми модель.

# %% [markdown]
# #### Decision Tree

# %%
model = DecisionTreeRegressor()

parameters = {
    'max_depth': range(1, 11),
    'min_samples_leaf': range(1, 6),
    'random_state': [12345]
}

grid = GridSearchCV(model, parameters, scoring=scoring, cv=5, verbose=2)
grid.fit(features_train, target_final_train)

print('Лучшие параметры:', grid.best_params_)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] END max_depth=1, min_samples_leaf=1, random_state=12345; total time=   0.1s
# [CV] END max_depth=1, min_samples_leaf=1, random_state=12345; total time=   0.1s
# [CV] END max_depth=1, min_samples_leaf=1, random_state=12345; total time=   0.1s
# [CV] END max_depth=1, min_samples_leaf=1, random_state=12345; total time=   0.1s
# [CV] END max_depth=1, min_samples_leaf=1, random_state=12345; total time=   0.1s
# [CV] END max_depth=1, min_samples_leaf=2, random_state=12345; total time=   0.1s
# [CV] END max_depth=1, min_samples_leaf=2, random_state=12345; total time=   0.1s
# [CV] END max_depth=1, min_samples_leaf=2, random_state=12345; total time=   0.1s
# [CV] END max_depth=1, min_samples_leaf=2, random_state=12345; total time=   0.1s
# [CV] END max_depth=1, min_samples_leaf=2, random_state=12345; total time=   0.1s
# [CV] END max_depth=1, min_samples_leaf=3, random_state=12345; total time=   0.1s
# ...

# %%
model = DecisionTreeRegressor(random_state=12345, max_depth=2, min_samples_leaf=1)
scores = cross_val_score(model, features_train, target_final_train, cv=5, scoring=scoring)
score = np.abs(sum(scores) / len(scores))
print('Средняя оценка качества модели:', score)

metrics.loc['Decision Tree', 'score_final'] = score
# Out:
# Средняя оценка качества модели: 10.819970329775767

# %% [markdown]
# #### Random Forest

# %%
model = RandomForestRegressor()

parameters = {
    'max_depth': range(1, 6),
    'min_samples_leaf': range(1, 6),
    'n_estimators': range(1, 22, 10),
    'random_state': [12345]
}

grid = GridSearchCV(model, parameters, scoring=scoring, cv=5, verbose=2)
grid.fit(features_train, target_final_train)

print('Лучшие параметры:', grid.best_params_)
# Out:
# Fitting 5 folds for each of 75 candidates, totalling 375 fits
# [CV] END max_depth=1, min_samples_leaf=1, n_estimators=1, random_state=12345; total time=   0.1s
# [CV] END max_depth=1, min_samples_leaf=1, n_estimators=1, random_state=12345; total time=   0.1s
# [CV] END max_depth=1, min_samples_leaf=1, n_estimators=1, random_state=12345; total time=   0.1s
# [CV] END max_depth=1, min_samples_leaf=1, n_estimators=1, random_state=12345; total time=   0.1s
# [CV] END max_depth=1, min_samples_leaf=1, n_estimators=1, random_state=12345; total time=   0.1s
# [CV] END max_depth=1, min_samples_leaf=1, n_estimators=11, random_state=12345; total time=   0.5s
# [CV] END max_depth=1, min_samples_leaf=1, n_estimators=11, random_state=12345; total time=   0.5s
# [CV] END max_depth=1, min_samples_leaf=1, n_estimators=11, random_state=12345; total time=   0.5s
# [CV] END max_depth=1, min_samples_leaf=1, n_estimators=11, random_state=12345; total time=   0.5s
# ...

# %%
model = RandomForestRegressor(random_state=12345, max_depth=5, min_samples_leaf=3, n_estimators=11)
scores = cross_val_score(model, features_train, target_final_train, cv=5, scoring=scoring)
score = np.abs(sum(scores) / len(scores))
print('Средняя оценка качества модели:', score)

metrics.loc['Random Forest', 'score_final'] = score
# Out:
# Средняя оценка качества модели: 10.201450457970257

# %% [markdown]
# Наилучший результат дала модель случайного леса с параметрами `max_depth=5, min_samples_leaf=3, n_estimators=11`.

# %%
for i in range(metrics.shape[0]):
    metrics.iloc[i, 2] = final_smape(metrics.iloc[i, 0], metrics.iloc[i, 1])

# %% [markdown]
# Посмотрим на получившиеся метрики:

# %%
metrics
# Out:
#                   score_rougher score_final score_total
# Dummy Regressor       11.886706   11.343681   11.479437
# Linear Regression     12.767081   12.268816   12.393382
# Decision Tree         11.282725    10.81997   10.935659
# Random Forest         10.981462    10.20145   10.396453

# %% [markdown]
# **Вывод**:
# В данном разделе мы выделили обучающую и тестовую выборку для моделирования, отмасштабировали данные, добавили метрику качества, а также нашли при помощи кросс-валидации наилучшую модель для прогнозирования показателя `final.output.recovery` и `rougher.output.recovery`.

# %% [markdown]
# ## Финальное тестирование

# %%
model = RandomForestRegressor(random_state=12345, max_depth=5, min_samples_leaf=1, n_estimators=21)
model.fit(features_train, target_rougher_train)
predicted_rough = model.predict(features_test)
score_rougher = smape(target_rougher_test, predicted_rough)

print('Средняя оценка качества модели:', score_rougher)
# Out:
# Средняя оценка качества модели: 6.593293434222694

# %%
model = RandomForestRegressor(random_state=12345, max_depth=5, min_samples_leaf=3, n_estimators=11)
model.fit(features_train, target_final_train)
predicted_final = model.predict(features_test)
score_final = smape(target_final_test, predicted_final)

print('Средняя оценка качества модели:', score_final)
# Out:
# Средняя оценка качества модели: 7.987905986238535

# %% [markdown]
# Можем заметить, что sMAPE в обоих случаях вышел даже меньше, чем при кросс-валидации.

# %%
# посчитаем итоговую метрику
score = final_smape(score_rougher, score_final)
score
# Out:
# 7.639252848234575

# %% [markdown]
# Итоговая метрика качества модели составила 7.64.

# %% [markdown]
# **Вывод:**:
# В данном разделе мы проверили выбранные модели случайного леса на тестовой выборке. Итоговая метрика качества sMAPE составила `7.64`.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# В ходе работы над данным проектом мы должны были подготовить прототип модели машинного обучения для компании «Цифры».
#
# Для решения данной задачи мы выполнили следующее:
# 1. Получили исходные данные.
# 1. Проверили правильность расчета эффективности обогащения.
# 1. Проанализировали недостающие данные в тестовой выборке.
# 1. Проанализировали и обработали пропуски в данных.
# 1. Провели исследовательский анализ данных.
# 1. Добавили функции для расчета итоговой метрика sMAPE.
# 1. Разбили данные на целевые признаки и переменные и отмасштабировали данные.
# 1. Выбрали наилучшую модель для прогноза первой целевой переменной при помощи кросс-валидации.
# 1. Выбрали наилучшую модель для прогноза второй целевой переменной при помощи кросс-валидации.
# 1. Провели финальное тестирование.
#
# Мы пришли к следующим важным выводам:
# - В процессе исследовательского анализа данных были обнаружены нулевые суммарные концентрации, возникающие на этапах флотации и очистки. Данные результаты были приняты за аномалии и удалены.
# - При подюоре при помощи кросс-валидации наилучших моделей для прогнозирования показателей `final.output.recovery` и `rougher.output.recovery` мы получили, что:
#     - наилучшая модель для `rougher.output.recovery`: случайный лес с параметрами `max_depth=5, min_samples_leaf=1, n_estimators=21`,
#     - наилучшая модель для `final.output.recovery`: случайный лес с параметрами `max_depth=5, min_samples_leaf=3, n_estimators=11`.
# - Итоговый sMAPE на выбранных моделях при кросс-валидации составил `10.4212`.
# - Итоговый sMAPE на выбранных моделях при проверке на тестовой выборке составил `7.64`.
#
# Таким образом, мы подготовили прототип модели машинного обучения с небольшими отклонениями прогнозирующей эффективность обогащения.
